# %%
import numpy as np
import pandas as pd
import dea.py
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [585], line 3
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 import dea.py
#
# ModuleNotFoundError: No module named 'dea.py'; 'dea' is not a package

# %%
rawData = pd.read_csv("/Users/dilshod/Downloads/RussianBankDataCorr.csv", index_col=0)

# %%
rawData
# Out:
#         id                name  year   tip                                pok  \
# 0        1  SBERBANK OF RUSSIA  2012   BIG                              index
# 1        1  SBERBANK OF RUSSIA  2012   BIG                             Assets
# 2        1  SBERBANK OF RUSSIA  2012   BIG                                CIR
# 3        1  SBERBANK OF RUSSIA  2012   BIG  CoefficientOfAdequacyOfOwnCapital
# 4        1  SBERBANK OF RUSSIA  2012   BIG     DepositsAndShort-termFinancing
# ...    ...                 ...   ...   ...                                ...
# 29541  315       SINERGIYA OAO  2017  NANO                               Data
# 29542  315       SINERGIYA OAO  2017  NANO                                DEP
# 29543  315       SINERGIYA OAO  2017  NANO                            TAssets
# 29544  315       SINERGIYA OAO  2017  NANO                                NIM
# 29545  315       SINERGIYA OAO  2017  NANO                                CAR
#
#               value
# 0      0.000000e+00
# 1      4.970714e+08
# 2      5.048000e+01
# 3      1.370000e+01
# 4      4.034643e+08
# ...             ...
# 29541  2.017000e+03
# 29542  4.868145e-01
# 29543  9.879656e+00
# 29544  1.080000e+01
# 29545  4.383000e+01
#
# [29546 rows x 6 columns]

# %%
data = rawData.drop(columns=['id', 'tip']).pivot_table(index=['name', 'year'], columns='pok', values='value').reset_index()

# %%
data['name'] = data['name'] + " " + data['year'].astype(str)
data = data.rename_axis(None, axis=1)
data = data.drop(columns=['year', 'Data', 'index'])
data = data.sort_values(by=['TAssets'], ascending=False)

# %%
data
# Out:
#                                                    name       Assets   CAR  \
# 1296                            SBERBANK OF RUSSIA 2013  556393068.0  13.4
# 1295                            SBERBANK OF RUSSIA 2012  497071356.0  13.7
# 1303                            SBERBANK OF RUSSIA 2020  487521621.0  14.7
# 1302                            SBERBANK OF RUSSIA 2019  483957068.0  14.8
# 1300                            SBERBANK OF RUSSIA 2017  470696273.0  13.0
# ...                                                 ...          ...   ...
# 840                                    KONTINENTAL 2016       7084.0  13.3
# 1294          SAVINGS AND LOANS SERVICES BANK, LLC 2015       5377.0  39.0
# 888                        LLC RNKO "EDINAYA KASSA 2016       5316.0  12.8
# 956                          NATIONAL SAVINGS BANK 2015       5224.0  10.0
# 992   NON-BANK CREDIT ORGANIZATION "INTERBANK CREDIT...       2169.0  38.2
#
#          CIR  CoefficientOfAdequacyOfOwnCapital       DEP  \
# 1296   45.73                               13.4  0.819575
# 1295   50.48                               13.7  0.811683
# 1303   36.24                               14.7  0.760626
# 1302   37.73                               14.8  0.747250
# 1300   35.23                               13.0  0.782648
# ...      ...                                ...       ...
# 840    63.37                               13.3  0.097120
# 1294   86.63                               39.0  0.072903
# 888    73.45                               12.8  0.374906
# 956    57.33                               10.0  0.141271
# 992   172.05                               38.2  0.039189
#
#       DepositsAndShort-termFinancing  InterestIncome   LOAN       NII    NIM  \
# 1296                     456005646.0      45176784.0  71.02  0.144725   5.97
# 1295                     403464273.0      38103295.0  69.54  0.172411   6.44
# 1303                     370821539.0      32477527.0  64.93  0.209821   5.43
# 1302                     361637148.0      38704030.0  67.97  0.198045   5.41
# 1300                     368389338.0      37003343.0  68.19  0.192468   5.81
# ...                              ...             ...    ...       ...    ...
# 840                            688.0           802.0  71.00  0.167186  16.13
# 1294                           392.0           627.0    NaN  0.279310  13.09
# 888                           1993.0            31.0  58.93  0.977504   1.29
# 956                            738.0          1148.0  41.38  0.290043  24.93
# 992                             85.0            96.0    NaN  0.775701   2.10
#
#       NetInterestMargin        OOD  OtherOperatingIncome   ROA    ROE   RQA  \
# 1296               5.97   583577.0             7644550.0  2.17  20.66  4.51
# 1295               6.44  1293925.0             7938049.0  2.68  24.06  5.11
# 1303               5.43  1784078.0             8623946.0  2.30  15.95  6.49
# 1302               5.41   297226.0             9558086.0  2.76  20.26  6.37
# 1300               5.81  1397565.0             8819414.0  2.73  22.87  7.05
# ...                 ...        ...                   ...   ...    ...   ...
# 840               16.13       60.0                 161.0  3.54   5.05   NaN
# 1294              13.09      108.0                 243.0  2.23   2.51   NaN
# 888                1.29        1.0                1347.0  6.17  13.06   NaN
# 956               24.93      265.0                 469.0  2.59   3.14  9.41
# 992                2.10      328.0                 332.0 -4.55 -10.32   NaN
#
#         TAssets  Tier1
# 1296  20.136986   10.6
# 1295  20.024244   10.4
# 1303  20.004845   14.3
# 1302  19.997507   14.5
# 1300  19.969724   11.4
# ...         ...    ...
# 840    8.865594    9.7
# 1294   8.589886    NaN
# 888    8.578476   10.1
# 956    8.561019    6.0
# 992    7.682022    NaN
#
# [1504 rows x 19 columns]

# %%
# data[['Assets', 'DepositsAndShort-termFinancing', 'InterestIncome', 'OtherOperatingIncome']] = data[['Assets', 'DepositsAndShort-termFinancing', 'InterestIncome', 'OtherOperatingIncome']] * 1e-6

# %%
# roa = (net_income + interest_expense) / Total Assets => net_income = roa * TAssets - interest_expense

# %%
# owners_equity, operatioanl_expenses -> operational_income, net_income

# %% [markdown]
# Чистая процентная маржа, NIM (Net Interest Margin) – коэффициент, характеризующий эффективность проведения активных операций. Это один из основных показателей, применяемый для оценки динамики процентных доходов банка и стоимость его фондирования относительно активов.

# %% [markdown]
# Отличие между показателями заключается в том, что в расчёт ROA включаются все активы, в том числе привлечённые, а в расчёт ROE - только собственные. Разница между ними демонстрирует, насколько велик так называемый «финансовый рычаг» (доля привлечённых ресурсов): чем она больше, тем больше размер финансового рычага.

# %%
dea_features = data[['name', 'DepositsAndShort-termFinancing', 'ROE', 'InterestIncome', 'NIM']]

# %%
dea_features
# Out:
#                                                    name  \
# 1296                            SBERBANK OF RUSSIA 2013
# 1295                            SBERBANK OF RUSSIA 2012
# 1303                            SBERBANK OF RUSSIA 2020
# 1302                            SBERBANK OF RUSSIA 2019
# 1300                            SBERBANK OF RUSSIA 2017
# ...                                                 ...
# 840                                    KONTINENTAL 2016
# 1294          SAVINGS AND LOANS SERVICES BANK, LLC 2015
# 888                        LLC RNKO "EDINAYA KASSA 2016
# 956                          NATIONAL SAVINGS BANK 2015
# 992   NON-BANK CREDIT ORGANIZATION "INTERBANK CREDIT...
#
#       DepositsAndShort-termFinancing    ROE  InterestIncome    NIM
# 1296                     456005646.0  20.66      45176784.0   5.97
# 1295                     403464273.0  24.06      38103295.0   6.44
# 1303                     370821539.0  15.95      32477527.0   5.43
# 1302                     361637148.0  20.26      38704030.0   5.41
# 1300                     368389338.0  22.87      37003343.0   5.81
# ...                              ...    ...             ...    ...
# 840                            688.0   5.05           802.0  16.13
# 1294                           392.0   2.51           627.0  13.09
# 888                           1993.0  13.06            31.0   1.29
# 956                            738.0   3.14          1148.0  24.93
# 992                             85.0 -10.32            96.0   2.10
#
# [1504 rows x 5 columns]
